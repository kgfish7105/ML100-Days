# %% [markdown]
# # 作業1

# %%
我選擇Kaggle的Huge Stock Market Dataset

1.你選的這組資料為何重要

A: 這組資料是Kaggle的資料集，目的是好玩

2.資料從何而來

A: Kaggle提供的dataset，獲得最多votes

3.蒐集而來的資料型態為何

A: 結構化的表格

4.這組資料想解決的問題如何評估

A: 回歸問題 => 預測股價漲跌

# %% [markdown]
# # 作業2

# %%
想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績， 請你思考並描述你如何規劃整體的分析/解決方案：

核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
解決路徑最佳化
得到目的地 與 乘客出發位置
算出實際可能路徑、所需時間
考慮司機、乘客意願程度

資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
a. 空間問題 : 當下有無道路施工阻礙
b. 時間問題 : 實際路徑時間 與 當下車況堵塞的所需時間

蒐集而來的資料型態為何
結構化的表格資料
距離 對應 時間

你要回答的問題，其如何評估 (tips：你的假設如何驗證)
實際所需距離 對應 理論所需距離
實際所需時間 對應 理論所需時間

# %% [markdown]
# ## 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_squared_error(y, yp):
    """
    請完成這個 Function 後往下執行
    """
    mse = sum(pow(abs(y - yp),2)) / len(y)
    return mse

# %%
def mean_absolute_error(y, yp):
    """
    計算 MAE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mae: MAE
    """
    mae = sum(abs(y - yp)) / len(y)
    return mae

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 222.727
# The Mean absolute error is 11.820
